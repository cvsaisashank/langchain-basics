# %% [markdown]
# # What is an Agent
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # What is an Agent Executor
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## important - About how docs show to execute Agent + AgentExecutor
#
# ![image.png](attachment:image.png)
#
# In the above screenshot, it goes and creates teh agent automatically for us.
#
# All approaches yield the same result, the one in the above screenshot and the one in main.py file.

# %% [markdown]
# # What is agent_scratchpad?

# %% [markdown]
# It is like a simplified form of memory.
#
# ![image.png](attachment:image.png)
#
# It stores the humanMessage, AIMessage and the FunctionMessage.
