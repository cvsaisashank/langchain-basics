# %% [markdown]
# ## Defining a tool

# %% [markdown]
# Tool is going to take the configutation given and then Serialize to a `function object` like below:
#
# ![define-a-tool.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
numbers = [1,2,3,4]

print(*numbers)
# Out:
# 1 2 3 4

# %%
list = ['red1', 'blue', 'green']
test, blue, green = list
print("before_unpacking", list)

print("after unpacking", *list)

print("test variable", test)
# Out:
# before_unpacking ['red1', 'blue', 'green']
# after unpacking red1 blue green
# test variable red1

# %%
class RPS:
  name
  def __init__(self):
    print("Welcome to RPS 900!")

# %%
rps_instance_1 = RPS()
rps_instance_1.play_game()

rps_instance_2 = RPS()
rps_instance_2.play_game()
# Out:
# Welcome to RPS 900!

# %%
test_tuple = (1,2,3)
one, two, three = test_tuple
print(one)

print(three)
# Out:
# 1
# 3
